# %% [markdown]
# <a href="https://colab.research.google.com/github/Sukyeong02/23-2-ANN/blob/main/Lecture_06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow import keras
from keras import Sequential, Input
from keras.layers import Dense

# %%
x = np.array([2,4,6,8,10,12,14])
y = np.array([0]*3 + [1]*4)

# %%
model = Sequential()
model.add(Input(shape=(1,)))
model.add(Dense(1,activation = 'sigmoid'))

model.compile(optimizer = 'sgd', loss = 'binary_crossentropy')
model.fit(x, y, epochs = 3000)
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# 1/1 [==============================] - 0s 9ms/step - loss: 0.4373
# Epoch 502/3000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.4371
# Epoch 503/3000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.4369
# Epoch 504/3000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.4368
# Epoch 505/3000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.4366
# Epoch 506/3000
# 1/1 [==============================] - 0s 10ms/step - loss: 0.4364
# Epoch 507/3000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.4363
# Epoch 508/3000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.4361
# Epoch 509/3000
# 1/1 [==============================] - 0s 12ms/step - loss: 0.4359
# Epoch 510/3000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.4358
# Epoch 511/3000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.4356
# Epoch 512/3000
# ...

# %%
plt.figure()
plt.scatter(x, y, marker='o', c='k', s=100)
plt.plot(x, model.predict(x), marker='*', c='r', markersize=15)
plt.xlabel('Study Time(x)')
plt.ylabel('Pass or Failure')
plt.grid(True)
plt.show()

hour = 8
prediction = model.predict([hour])

print('%.f시간을 공부할 경우, 합격 예상 확률은 %.2f%%입니다.' %(hour, prediction * 100))
# Out:
# ...
# 1/1 [==============================] - 0s 116ms/step
# 8시간을 공부할 경우, 합격 예상 확률은 72.37%입니다.
